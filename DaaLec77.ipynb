# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl
#python -m pip install openpyxl
# Out:
#   Cell In[6], line 1
#     pip install openpyxl
#         ^
# SyntaxError: invalid syntax

# %%
cus = pd.read_excel(
    r"C:\Users\dell\Downloads\Ecomm (1).xlsx",
    sheet_name="CustomerDetail"
)

# %%
cus.shape
# Out:
# (24, 12)

# %%
order=pd.read_excel(r"C:\Users\dell\Downloads\Ecomm (1).xlsx",sheet_name="Jan")

# %%
order.shape
# Out:
# (1952, 8)

# %%
cus.head(2)
# Out:
#   CustomerID  CustomerID.1 Order Date  Month MonthName  DateInText  \
# 0    CUS7253          7253 2015-01-07      1       Jan  01/07/2015
# 1    CUS4875          4875 2015-06-13      6       Jun  06/13/2015
#
#     Customer Name State or Province         City Gender  Gender.1 Gender.2
# 0   Bonnie Potter        Washington    Anacortes      M         1     MALE
# 1  Ronnie Proctor        California  San Gabriel      F         0   FEMALE

# %%
cus=cus.drop(columns=['CustomerID','Month','MonthName','DateInText','Gender','Gender.1'])

# %%
cus = cus.rename(columns={'CustomerID.1':'CustomerID','Gender.2':'Gender'})

# %%
cus.head(2)
# Out:
#    CustomerID Order Date   Customer Name State or Province         City  \
# 0        7253 2015-01-07   Bonnie Potter        Washington    Anacortes
# 1        4875 2015-06-13  Ronnie Proctor        California  San Gabriel
#
#    Gender
# 0    MALE
# 1  FEMALE

# %%
cus.isnull().sum()
# Out:
# CustomerID           0
# Order Date           0
# Customer Name        0
# State or Province    0
# City                 0
# Gender               0
# dtype: int64

# %%
cus = cus.dropna()

# %%
cus.duplicated().sum()
# Out:
# np.int64(0)

# %%
cus = cus.drop_duplicates()

# %%
cus.shape
# Out:
# (24, 6)

# %%
cus.head()
# Out:
#    CustomerID Order Date      Customer Name State or Province         City  \
# 0        7253 2015-01-07      Bonnie Potter        Washington    Anacortes
# 1        4875 2015-06-13     Ronnie Proctor        California  San Gabriel
# 2        2748 2015-02-15      Marcus Dunlap        New Jersey      Roselle
# 3        4565 2015-05-12  Gwendolyn F Tyson         Minnesota   Prior Lake
# 4        4666 2015-05-12  Gwendolyn F Tyson         Minnesota   Prior Lake
#
#    Gender
# 0    MALE
# 1  FEMALE
# 2    MALE
# 3    MALE
# 4    MALE

# %%
order.head()
# Out:
#    Order ID  CustomerID   Amount     Profit  Quantity ordered new  \
# 0     88522        4666    11.36     4.5600                     4
# 1     90193        4663  6011.76  4390.3665                    12
# 2     90192        2583   208.56   -53.8096                    22
# 3     86838        8372  1259.04   803.4705                    16
# 4     86838        6458    22.96   -24.0300                     7
#
#   Product Category Product Sub-Category Payment Mode
# 0  Office Supplies  Pens & Art Supplies  Credit Card
# 1        Furniture   Chairs & Chairmats  Credit Card
# 2        Furniture   Office Furnishings  Credit Card
# 3        Furniture   Office Furnishings  Credit Card
# 4  Office Supplies  Pens & Art Supplies  Credit Card

# %%
order.isnull().sum()
# Out:
# Order ID                0
# CustomerID              0
# Amount                  0
# Profit                  0
# Quantity ordered new    0
# Product Category        0
# Product Sub-Category    0
# Payment Mode            0
# dtype: int64

# %%
order = order.dropna()

# %%
order.Profit.sum()
# Out:
# np.float64(224114.64183714997)

# %%
order['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
order.groupby('Product Category')['Profit'].sum()
# Out:
# Product Category
# Furniture          59249.445936
# Office Supplies    89562.039537
# Technology         75303.156364
# Name: Profit, dtype: float64

# %%
order.groupby('Product Category').agg({'Profit':'sum'})
# Out:
#                         Profit
# Product Category
# Furniture         59249.445936
# Office Supplies   89562.039537
# Technology        75303.156364

# %%
order.groupby('Product Category').agg({'Profit':'sum'}).reset_index()
# Out:
#   Product Category        Profit
# 0        Furniture  59249.445936
# 1  Office Supplies  89562.039537
# 2       Technology  75303.156364

# %%
pbp = order.groupby('Product Category').agg({'Profit':'sum'}).reset_index()

# %%
pbp
# Out:
#   Product Category        Profit
# 0        Furniture  59249.445936
# 1  Office Supplies  89562.039537
# 2       Technology  75303.156364

# %%
#Merge Dataset
df = pd.merge(cus, order, on='CustomerID', how='inner')

# %%
df.shape
# Out:
# (1952, 13)

# %%
df.head()
# Out:
#    CustomerID Order Date      Customer Name State or Province        City  \
# 0        4666 2015-05-12  Gwendolyn F Tyson         Minnesota  Prior Lake
# 1        4666 2015-05-12  Gwendolyn F Tyson         Minnesota  Prior Lake
# 2        4666 2015-05-12  Gwendolyn F Tyson         Minnesota  Prior Lake
# 3        4666 2015-05-12  Gwendolyn F Tyson         Minnesota  Prior Lake
# 4        4666 2015-05-12  Gwendolyn F Tyson         Minnesota  Prior Lake
#
#   Gender  Order ID   Amount       Profit  Quantity ordered new  \
# 0   MALE     88522    11.36     4.560000                     4
# 1   MALE     90669    94.27   105.678000                    11
# 2   MALE     86297   285.84 -2177.986096                     9
# 3   MALE     89320  1982.14  1372.630800                    31
# 4   MALE     90910  7149.87  4637.407200                    13
#
#   Product Category           Product Sub-Category Payment Mode
# 0  Office Supplies            Pens & Art Supplies  Credit Card
# ...

# %%
df.groupby("State or Province").agg({"Profit":'sum'}).reset_index()
# Out:
#   State or Province        Profit
# 0        California  31886.448316
# 1         Minnesota  34330.365504
# 2           Montana  15291.345669
# 3          New York  98143.568974
# 4            Oregon  44462.913374

# %%
df.groupby("State or Province").agg({"Amount":'sum',"Profit":'sum'}).reset_index()
# Out:
#   State or Province     Amount        Profit
# 0        California  504316.36  31886.448316
# 1         Minnesota  127080.87  34330.365504
# 2           Montana  270342.99  15291.345669
# 3          New York  840499.42  98143.568974
# 4            Oregon  242224.79  44462.913374

# %%
pbs=df.groupby("State or Province").agg({"Amount":'sum',"Profit":'sum'}).reset_index()

# %%
pbs
# Out:
#   State or Province     Amount        Profit
# 0        California  504316.36  31886.448316
# 1         Minnesota  127080.87  34330.365504
# 2           Montana  270342.99  15291.345669
# 3          New York  840499.42  98143.568974
# 4            Oregon  242224.79  44462.913374

# %%
pbs.Profit = pbs.Profit.map(lambda val:round(val,2))

# %%
pbs
# Out:
#   State or Province     Amount    Profit
# 0        California  504316.36  31886.45
# 1         Minnesota  127080.87  34330.37
# 2           Montana  270342.99  15291.35
# 3          New York  840499.42  98143.57
# 4            Oregon  242224.79  44462.91
